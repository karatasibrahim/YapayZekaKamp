# %% [markdown]
#  # <font color="green"> Pyhtona Giriş</font>

# %% [markdown]
# LATEX $\int^b_a \frac{dx}{tanhx}\Sigma $

# %% [markdown]
# # Değişken Tanımları

# %%
a=5

# %%
a*5
# Out:
# 25

# %%
b=3

# %%
c=a+b

# %%
c
# Out:
# 8

# %%
liste=["ali","veli","yirmi"]

# %%
print(liste)
# Out:
# ['ali', 'veli', 'yirmi']

# %%
for i in liste: print (i)
# Out:
# ali
# veli
# yirmi

# %%
map(liste)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 map(liste)
#
# TypeError: map() must have at least two arguments.

# %%
print.map(liste)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 print.map(liste)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'map'

# %%
'Ali dedi ki "Merhaba"'
# Out:
# 'Ali dedi ki "Merhaba"'

# %%
"Ali'nin adresi"
# Out:
# "Ali'nin adresi"

# %%
yil=2022
ay="Ekim"

# %%
sonuc=2025-yil

# %%
sonuc
# Out:
# 3

# %% [markdown]
# # Operatörler

# %%
note=int(input("Notunuzu giriniz: "))
# Out:
# Notunuzu giriniz: 95

# %%
if note>=90 : 
    print ("A")
    elif note>=80:
        print ("B")
        else:
          print("F")
# Out:
#   Input In [28]
#     elif note>=80:
#     ^
# SyntaxError: invalid syntax

# %%
if note>=90:
    print("A")
elif note>=80:
    print("B")
else:
    print("F")
# Out:
# A

# %%
for i in range (10): print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 416          417         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 416  Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 416      1  28220  32.5   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Age"].hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].min()
# Out:
# 0.42

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue="Survived")

# %%
df[df["Age" && ]<18]
# Out:
#   Input In [73]
#     df[df["Age" && ]<18]
#                  ^
# SyntaxError: invalid syntax

# %%
df[(df["Age"]<18) & (df["Pclass"]==3)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                      ...
# 844          845         0       3                      Culumovic, Mr. Jeso
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1878-5713
#
#  Directory of C:\Users\ibrah\Documents\yapayzeka\day1
#
# 01.10.2022  12:52    <DIR>          .
# 01.10.2022  12:52    <DIR>          ..
# 01.10.2022  10:59    <DIR>          .ipynb_checkpoints
# 12.08.2022  22:41            11.658 excel-comp-data.xlsx
# 01.10.2022  12:52           468.587 PythonGiris.ipynb
# 12.08.2022  22:41             5.552 sales-estimate.xlsx
# 12.08.2022  22:41             5.680 sales-funnel.xlsx
# 12.08.2022  22:41                40 test_pandas.csv
# 12.08.2022  22:41            36.864 test_pandas.db
# 12.08.2022  22:41            30.093 test_pandas.xlsm
# 12.08.2022  22:41                43 test_pandas_no_header.csv
# 12.08.2022  22:41             6.068 test_sheets.xlsx
# 12.08.2022  22:41            62.086 train.csv
#               10 File(s)        626.671 bytes
#                3 Dir(s)  143.209.156.608 bytes free

# %%
df=pd.read_excel("sales-funnel.xlsx")

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df=pd.read_excel("sales-estimate.xlsx")

# %%
df.head()
# Out:
#    Account                          Name State            Rep       Manager  \
# 0   714466               Trantow-Barrows    MN   Craig Booker  Debra Henley
# 1   737550  Fritsch, Russel and Anderson    MN   Craig Booker  Debra Henley
# 2   146832                  Kiehn-Spinka    TX  Daniel Hilton  Debra Henley
# 3   218895                     Kulas Inc    TX  Daniel Hilton  Debra Henley
# 4   412290                 Jerde-Hilpert    WI     John Smith  Debra Henley
#
#    Current_Price  Quantity  New_Product_Price
# 0            500       100                550
# 1            600        90                725
# 2            225       475                255
# 3            290       375                300
# 4            375       400                400

# %%
df.describe()
# Out:
#              Account  Current_Price    Quantity  New_Product_Price
# count      12.000000      12.000000   12.000000          12.000000
# mean   436776.500000     405.416667  230.416667         447.083333
# std    262600.384263     123.811777  153.851439         146.480814
# min    141962.000000     225.000000   75.000000         255.000000
# 25%    205025.250000     297.500000  100.000000         337.500000
# 50%    359944.500000     387.500000  175.000000         412.500000
# 75%    718307.750000     512.500000  381.250000         562.500000
# max    740150.000000     600.000000  475.000000         725.000000

# %%
pip install gtts
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   WARNING: The script gtts-cli.exe is installed in 'C:\Users\ibrah\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
from gtts import gTTS
text="Welcome to our best data science class"
kayit=gTTS(text=text,lang="en", slow=False)
kayit.save("konusma.mp3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 from gtts import gTTS
#       2 text="Welcome to our best data science class"
#       3 kayit=gTTS(text=text,lang="en", slow=False)
#
# ModuleNotFoundError: No module named 'gtts'

# %%
pip install gtts
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# ...

# %%
from gtts import gTTS
text="Welcome to our best data science class"
kayit=gTTS(text=text,lang="en", slow=False)
kayit.save("konusma.mp3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 from gtts import gTTS
#       2 text="Welcome to our best data science class"
#       3 kayit=gTTS(text=text,lang="en", slow=False)
#
# ModuleNotFoundError: No module named 'gtts'
