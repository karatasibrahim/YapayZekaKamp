# %%
#pip install twython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting twython
#   Downloading twython-3.9.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in c:\users\ibrah\appdata\roaming\python\python39\site-packages (from twython) (1.3.1)
# Requirement already satisfied: requests>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from twython) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ibrah\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.4.0->twython) (3.2.2)
# Installing collected packages: twython
# Successfully installed twython-3.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from twython import Twython

# %%
dir(Twython)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_error_message',
#  '_request',
#  'add_list_member',
#  'construct_api_url',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_list_members',
#  'create_metadata',
#  'create_mute',
#  'create_place',
#  'create_saved_search',
#  'cursor',
#  'delete',
#  'delete_list',
#  'delete_list_member',
#  'delete_list_members',
#  'destroy_block',
#  'destroy_direct_message',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'encode',
#  'get',
#  'get_account_settings',
#  'get_application_rate_limit_status',
#  'get_authentication_tokens',
#  'get_authorized_tokens',
#  'get_available_trends',
#  'get_closest_trends',
#  'get_contributees',
#  'get_contributors',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_followers_ids',
#  'get_followers_list',
#  'get_friends_ids',
#  'get_friends_list',
#  'get_geo_info',
#  'get_home_timeline',
#  'get_incoming_friendship_ids',
#  'get_lastfunction_header',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_statuses',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_mentions_timeline',
#  'get_oembed_tweet',
#  'get_outgoing_friendship_ids',
#  'get_place_trends',
#  'get_privacy_policy',
#  'get_profile_banner_sizes',
#  'get_retweeters_ids',
#  'get_retweets',
#  'get_saved_searches',
#  'get_sent_messages',
#  'get_similar_places',
#  'get_specific_list',
#  'get_supported_languages',
#  'get_tos',
#  'get_twitter_configuration',
#  'get_user_ids_of_blocked_retweets',
#  'get_user_suggestions',
#  'get_user_suggestions_by_slug',
#  'get_user_suggestions_statuses_by_slug',
#  'get_user_timeline',
#  'html_for_tweet',
#  'invalidate_token',
#  'is_list_member',
#  'is_list_subscriber',
#  'list_block_ids',
#  'list_blocks',
#  'list_mute_ids',
#  'list_mutes',
#  'lookup_friendships',
#  'lookup_status',
#  'lookup_user',
#  'obtain_access_token',
#  'post',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retweet',
#  'retweeted_of_me',
#  'reverse_geocode',
#  'search',
#  'search_gen',
#  'search_geo',
#  'search_users',
#  'send_direct_message',
#  'show_friendship',
#  'show_lists',
#  'show_owned_lists',
#  'show_saved_search',
#  'show_status',
#  'show_user',
#  'subscribe_to_list',
#  'unicode2utf8',
#  'unsubscribe_from_list',
#  'update_account_settings',
#  'update_delivery_service',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_background_image',
#  'update_profile_banner_image',
#  'update_profile_colors',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_media',
#  'upload_video',
#  'verify_credentials']

# %%
CONSUMER_KEY = '0pJRCT1emkOcrtxHl7lMN4N5A'
CONSUMER_SECRET = 'IS4Gxcx1aQ1c5Hyei5PSePLS37IcVmYBT8Qt1t4IOxmLIxJD42'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

# %%
results=twitter.search(q="29 Ekim",count=100) #Güncel Togg kelimesi ile ilgili geçen 100 kayıt

# %%
results
# Out:
# {'statuses': [{'created_at': 'Sun Oct 30 06:57:28 +0000 2022',
#    'id': 1586613237147398144,
#    'id_str': '1586613237147398144',
#    'text': "RT @avmustafakose: Türkiye Cumhuriyeti 99 yaşında:\nCumhuriyetimiz’in kurucusu Gazi Mustafa Kemal Atatürk başta olmak üzere Milli Mücadele'n…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'avmustafakose',
#       'name': 'Av. Mustafa KÖSE 🇹🇷',
#       'id': 479635805,
#       'id_str': '479635805',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1476852564,
#     'id_str': '1476852564',
#     'name': 'HAYATİ DEMİR',
#     'screen_name': 'kaman4006',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 368,
#     'friends_count': 1213,
#     'listed_count': 0,
#     'created_at': 'Sun Jun 02 09:25:01 +0000 2013',
#     'favourites_count': 31658,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 19310,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/840205540353560576/J8HpvlfN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/840205540353560576/J8HpvlfN_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 08:08:40 +0000 2022',
#     'id': 1586268766463479808,
#     'id_str': '1586268766463479808',
#     'text': 'Türkiye Cumhuriyeti 99 yaşında:\nCumhuriyetimiz’in kurucusu Gazi Mustafa Kemal Atatürk başta olmak üzere Milli Mücad… https://t.co/4l0Tb0rTeC',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/4l0Tb0rTeC',
#        'expanded_url': 'https://twitter.com/i/web/status/1586268766463479808',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 479635805,
#      'id_str': '479635805',
#      'name': 'Av. Mustafa KÖSE 🇹🇷',
#      'screen_name': 'avmustafakose',
#      'location': 'ANTALYA',
#      'description': 'Ak Parti Antalya Milletvekili / Ak Parti MKYK Üyesi / TBMM Anayasa Komisyonu Üyesi /  Genel Merkez Teşkilat Bşk.Yrd. / Türkiye-Brezilya Dostluk Grubu Başkanı',
#      'url': 'https://t.co/WuR8MiJNIU',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/WuR8MiJNIU',
#          'expanded_url': 'http://www.mustafakose.com.tr',
#          'display_url': 'mustafakose.com.tr',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 189007,
#      'friends_count': 3023,
#      'listed_count': 127,
#      'created_at': 'Tue Jan 31 16:06:47 +0000 2012',
#      'favourites_count': 24752,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 30551,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/888065794021748736/1nnHyvNe_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/888065794021748736/1nnHyvNe_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/479635805/1461924999',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 42,
#     'favorite_count': 203,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 42,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Sun Oct 30 06:57:27 +0000 2022',
#    'id': 1586613234337030145,
#    'id_str': '1586613234337030145',
#    'text': 'RT @liberaLDP: Tüm halkımızın 29 Ekim Cumhuriyet Bayramı kutlu olsun! #29EkimCumhiyetBayramı #ldp #liberaldemokratparti https://t.co/H3mi3x…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': '29EkimCumhiyetBayramı',
#       'indices': [70, 92]},
#      {'text': 'ldp', 'indices': [93, 97]},
#      {'text': 'liberaldemokratparti', 'indices': [98, 119]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'liberaLDP',
#       'name': 'Liberal Demokrat Parti',
#       'id': 70586612,
#       'id_str': '70586612',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1548889838472073217,
#     'id_str': '1548889838472073217',
#     'name': 'Eren Gaert',
#     'screen_name': 'ErenMathers0',
#     'location': '',
#     'description': '🗽🇺🇸🇹🇷',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 27,
#     'friends_count': 59,
#     'listed_count': 0,
#     'created_at': 'Mon Jul 18 04:38:19 +0000 2022',
#     'favourites_count': 1694,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 922,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1579555512261218304/Dj6GwMdL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1579555512261218304/Dj6GwMdL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1548889838472073217/1660334023',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Oct 28 21:00:27 +0000 2022',
#     'id': 1586100606150008832,
#     'id_str': '1586100606150008832',
#     'text': 'Tüm halkımızın 29 Ekim Cumhuriyet Bayramı kutlu olsun! #29EkimCumhiyetBayramı #ldp #liberaldemokratparti https://t.co/H3mi3xlOzX',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': '29EkimCumhiyetBayramı',
#        'indices': [55, 77]},
#       {'text': 'ldp', 'indices': [78, 82]},
#       {'text': 'liberaldemokratparti', 'indices': [83, 104]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1586100594443538433,
#        'id_str': '1586100594443538433',
#        'indices': [105, 128],
#        'media_url': 'http://pbs.twimg.com/media/FgL2Fk3X0AEpKqU.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FgL2Fk3X0AEpKqU.jpg',
#        'url': 'https://t.co/H3mi3xlOzX',
#        'display_url': 'pic.twitter.com/H3mi3xlOzX',
#        'expanded_url': 'https://twitter.com/liberaLDP/status/1586100606150008832/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 1600, 'h': 1600, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1586100594443538433,
#        'id_str': '1586100594443538433',
#        'indices': [105, 128],
#        'media_url': 'http://pbs.twimg.com/media/FgL2Fk3X0AEpKqU.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FgL2Fk3X0AEpKqU.jpg',
#        'url': 'https://t.co/H3mi3xlOzX',
#        'display_url': 'pic.twitter.com/H3mi3xlOzX',
#        'expanded_url': 'https://twitter.com/liberaLDP/status/1586100606150008832/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 1600, 'h': 1600, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 70586612,
#      'id_str': '70586612',
#      'name': 'Liberal Demokrat Parti',
#      'screen_name': 'liberaLDP',
#      'location': 'Meclis dışında',
#      'description': 'Liberal Demokrat Parti Resmi Twitter Hesabı',
#      'url': 'https://t.co/vuuSsuwhgM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/vuuSsuwhgM',
#          'expanded_url': 'http://ldp.org.tr',
#          'display_url': 'ldp.org.tr',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 158132,
#      'friends_count': 662,
#      'listed_count': 223,
#      'created_at': 'Tue Sep 01 03:30:03 +0000 2009',
#      'favourites_count': 5250,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 10315,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1523061194466156546/VO5u7u07_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1523061194466156546/VO5u7u07_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/70586612/1515230519',
#      'profile_link_color': '004CAB',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'regular',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 41,
#     'favorite_count': 286,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 41,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Sun Oct 30 06:57:24 +0000 2022',
#    'id': 1586613219438858240,
#    'id_str': '1586613219438858240',
#    'text': 'RT @tr_hbr: 🔥 TRT spikerinin 29 Ekim mesajı cezasız kalmadı: Ekranlardan çekildi!: TRT Haber spikerlerinden Deniz Demir, ana haber bültenin…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tr_hbr',
#       'name': '📰 TR HABER || Tüᴍ Hᴀʙᴇʀʟᴇʀ 🇹🇷',
#       'id': 904486768854097921,
#       'id_str': '904486768854097921',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 391612293,
#     'id_str': '391612293',
#     'name': 'hiç',
#     'screen_name': 'na_mevcut',
#     'location': '',
#     'description': 'Varlığımdan intihâsızlık terennüm eyliyen Bezm-i hiçide adem adlı rebâbım var benim! Kemalist yoldaşlarıma selam olsun.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 625,
#     'friends_count': 1530,
#     'listed_count': 1,
#     'created_at': 'Sat Oct 15 20:58:33 +0000 2011',
#     'favourites_count': 3996,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 89851,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000001091653/b4fca6b5222ed088fb113d9a1e25f449_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000001091653/b4fca6b5222ed088fb113d9a1e25f449_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Oct 30 06:43:37 +0000 2022',
#     'id': 1586609752158932992,
#     'id_str': '1586609752158932992',
#     'text': '🔥 TRT spikerinin 29 Ekim mesajı cezasız kalmadı: Ekranlardan çekildi!: TRT Haber spikerlerinden Deniz Demir, ana ha… https://t.co/mzeHvma80Q',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mzeHvma80Q',
#        'expanded_url': 'https://twitter.com/i/web/status/1586609752158932992',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 904486768854097921,
#      'id_str': '904486768854097921',
#      'name': '📰 TR HABER || Tüᴍ Hᴀʙᴇʀʟᴇʀ 🇹🇷',
#      'screen_name': 'tr_hbr',
#      'location': 'http://facebook.com/TRHaber4/',
#      'description': '🗣 Güçlü olana değil 🅳🅾🅶🆁🆄🆈🅰 🆃🅰🆁🅰🅵 Takip edin “HABERİNİZ” olsun! #TrHaber #TrNews',
#      'url': 'https://t.co/NyEWsZBwjS',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/NyEWsZBwjS',
#          'expanded_url': 'http://habersource.blogspot.com',
#          'display_url': 'habersource.blogspot.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 36400,
#      'friends_count': 34412,
#      'listed_count': 71,
#      'created_at': 'Sun Sep 03 23:30:25 +0000 2017',
#      'favourites_count': 86956,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 735738,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1383591639554224136/VuOZm8nS_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383591639554224136/VuOZm8nS_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/904486768854097921/1520095441',
#      'profile_link_color': 'FF0000',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Sun Oct 30 06:57:23 +0000 2022',
#    'id': 1586613218377596930,
#    'id_str': '1586613218377596930',
#    'text': 'Trabzon da Trabzonlu Trabzonspor  lu vatandaşlar 29 Ekim kutlaması yapıyor ve:\n"Kırmızı-beyaz en büyük Türkiye! Yaş… https://t.co/sBfk2wc8sZ',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/sBfk2wc8sZ',
#       'expanded_url': 'https://twitter.com/i/web/status/1586613218377596930',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1492502911737380865,
#     'id_str': '1492502911737380865',
#     'name': 'SBalcı29',
#     'screen_name': 'SBALCI29',
#     'location': '',
#     'description': '❤💙⭐ ⚖️ 🦂',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5810,
#     'friends_count': 5652,
#     'listed_count': 2,
#     'created_at': 'Sat Feb 12 14:17:04 +0000 2022',
#     'favourites_count': 27895,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 904,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1560718738126766080/CnGBrztZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1560718738126766080/CnGBrztZ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1492502911737380865/1651083964',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'tr'},
#   {'created_at': 'Sun Oct 30 06:57:23 +0000 2022',
#    'id': 1586613218365030400,
#    'id_str': '1586613218365030400',
#    'text': 'RT @tcbestepe: Türkiye Cumhuriyeti Cumhurbaşkanlığı olarak Cumhuriyetimizin ilanının 99. yıl dönümü ve 29 Ekim Cumhuriyet Bayramı’nı tebrik…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tcbestepe',
#       'name': 'T.C. Cumhurbaşkanlığı',
#       'id': 272613386,
#       'id_str': '272613386',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3027787005,
#     'id_str': '3027787005',
#     'name': 'Selçuk Şakalar 🇹🇷',
#     'screen_name': 'SelcukSakalar46',
#     'location': '',
#     'description': 'YOLUMUZ AK DAVAMIZ HAK..\n#instagramhesabımyoktur',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 861,
#     'friends_count': 705,
#     'listed_count': 0,
#     'created_at': 'Tue Feb 10 07:56:33 +0000 2015',
#     'favourites_count': 121356,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 18809,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1158052170043994113/9c6oqATY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1158052170043994113/9c6oqATY_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3027787005/1499288386',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 06:38:18 +0000 2022',
#     'id': 1586246025848754176,
#     'id_str': '1586246025848754176',
#     'text': 'Türkiye Cumhuriyeti Cumhurbaşkanlığı olarak Cumhuriyetimizin ilanının 99. yıl dönümü ve 29 Ekim Cumhuriyet Bayramı’… https://t.co/1lwgdv7puL',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1lwgdv7puL',
#        'expanded_url': 'https://twitter.com/i/web/status/1586246025848754176',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 272613386,
#      'id_str': '272613386',
#      'name': 'T.C. Cumhurbaşkanlığı',
#      'screen_name': 'tcbestepe',
#      'location': 'Ankara',
#      'description': '',
#      'url': 'https://t.co/j6S8rJH7CL',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/j6S8rJH7CL',
#          'expanded_url': 'https://www.tccb.gov.tr',
#          'display_url': 'tccb.gov.tr',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9196666,
#      'friends_count': 9,
#      'listed_count': 3752,
#      'created_at': 'Sat Mar 26 20:57:28 +0000 2011',
#      'favourites_count': 18,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 16972,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1152214087331471360/6tFUQM1K_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1152214087331471360/6tFUQM1K_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/272613386/1563356961',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1586245759720214530,
#     'quoted_status_id_str': '1586245759720214530',
#     'quoted_status': {'created_at': 'Sat Oct 29 06:37:14 +0000 2022',
#      'id': 1586245759720214530,
#      'id_str': '1586245759720214530',
#      'text': 'Bugün hep birlikte Türkiye Cumhuriyeti’nin 99. kuruluş yıl dönümüne kavuşmanın gurur ve heyecanını yaşıyoruz.\n\nÜlke… https://t.co/D5Agnu4ZKC',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/D5Agnu4ZKC',
#         'expanded_url': 'https://twitter.com/i/web/status/1586245759720214530',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#      'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 68034431,
#       'id_str': '68034431',
#       'name': 'Recep Tayyip Erdoğan',
#       'screen_name': 'RTErdogan',
#       'location': 'Ankara, Türkiye',
#       'description': 'Türkiye Cumhurbaşkanı ve AK Parti Genel Başkanı - President of Türkiye and AK Party Chairman',
#       'url': 'https://t.co/5wxa8a5Zek',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/5wxa8a5Zek',
#           'expanded_url': 'http://t.me/RTErdogan',
#           'display_url': 't.me/RTErdogan',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 19535566,
#       'friends_count': 104,
#       'listed_count': 13186,
#       'created_at': 'Sun Aug 23 01:13:44 +0000 2009',
#       'favourites_count': 93,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': True,
#       'statuses_count': 10246,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'FFFFFF',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1151410974240444416/yVvaD7hU_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1151410974240444416/yVvaD7hU_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/68034431/1666959008',
#       'profile_link_color': '1E9EB3',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'C0DFEC',
#       'profile_text_color': '333333',
#       'profile_use_background_image': False,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None,
#       'translator_type': 'regular',
#       'withheld_in_countries': []},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 5612,
#      'favorite_count': 16621,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'tr'},
#     'retweet_count': 554,
#     'favorite_count': 2048,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': True,
#    'quoted_status_id': 1586245759720214530,
#    'quoted_status_id_str': '1586245759720214530',
#    'retweet_count': 554,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Sun Oct 30 06:57:23 +0000 2022',
#    'id': 1586613218298019841,
#    'id_str': '1586613218298019841',
#    'text': 'RT @lvntozrn: Bursa Nilüfer İlçesi...\nYıllar sonra (araya pandemi girdi) muhteşem bir 29 Ekim Cumhuriyet Bayramı kutlaması yaşadık.\n📍 Atatü…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'lvntozrn',
#       'name': 'Levent Özeren',
#       'id': 3103049069,
#       'id_str': '3103049069',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1583574194897539079,
#     'id_str': '1583574194897539079',
#     'name': 'gulcinkip445@gmail.com',
#     'screen_name': 'gulcinkip445',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 27,
#     'listed_count': 0,
#     'created_at': 'Fri Oct 21 21:41:51 +0000 2022',
#     'favourites_count': 5,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 20:18:09 +0000 2022',
#     'id': 1586452350914658304,
#     'id_str': '1586452350914658304',
#     'text': 'Bursa Nilüfer İlçesi...\nYıllar sonra (araya pandemi girdi) muhteşem bir 29 Ekim Cumhuriyet Bayramı kutlaması yaşadı… https://t.co/PNjNR0fLFl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/PNjNR0fLFl',
#        'expanded_url': 'https://twitter.com/i/web/status/1586452350914658304',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3103049069,
#      'id_str': '3103049069',
#      'name': 'Levent Özeren',
#      'screen_name': 'lvntozrn',
#      'location': '',
#      'description': 'Olmazsa olmazlarım ;\nAtatürk, Türkiye, Cumhuriyet, Demokrasi, Adalet 🙋\u200d♂️',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 457188,
#      'friends_count': 1827,
#      'listed_count': 318,
#      'created_at': 'Sat Mar 21 22:52:31 +0000 2015',
#      'favourites_count': 144597,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 107832,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1514546257645252612/JS6DXkf6_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1514546257645252612/JS6DXkf6_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3103049069/1563103966',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 276,
#     'favorite_count': 3108,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 276,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Sun Oct 30 06:57:23 +0000 2022',
#    'id': 1586613216779575296,
#    'id_str': '1586613216779575296',
#    'text': "RT @pusholder: İstanbul'da 29 Ekim Cumhuriyet Bayramı 🇹🇷 https://t.co/SXmSuhA2hR",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'pusholder',
#       'name': 'Pusholder',
#       'id': 1212685850095452160,
#       'id_str': '1212685850095452160',
#       'indices': [3, 13]}],
#     'urls': [],
#     'media': [{'id': 1586468145803526145,
#       'id_str': '1586468145803526145',
#       'indices': [57, 80],
#       'media_url': 'http://pbs.twimg.com/media/FgREX4YXgAEOw2j.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FgREX4YXgAEOw2j.jpg',
#       'url': 'https://t.co/SXmSuhA2hR',
#       'display_url': 'pic.twitter.com/SXmSuhA2hR',
#       'expanded_url': 'https://twitter.com/pusholder/status/1586468156788412420/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1600, 'h': 1198, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 509, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 899, 'resize': 'fit'}},
#       'source_status_id': 1586468156788412420,
#       'source_status_id_str': '1586468156788412420',
#       'source_user_id': 1212685850095452160,
#       'source_user_id_str': '1212685850095452160'}]},
#    'extended_entities': {'media': [{'id': 1586468145803526145,
#       'id_str': '1586468145803526145',
#       'indices': [57, 80],
#       'media_url': 'http://pbs.twimg.com/media/FgREX4YXgAEOw2j.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FgREX4YXgAEOw2j.jpg',
#       'url': 'https://t.co/SXmSuhA2hR',
#       'display_url': 'pic.twitter.com/SXmSuhA2hR',
#       'expanded_url': 'https://twitter.com/pusholder/status/1586468156788412420/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1600, 'h': 1198, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 509, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 899, 'resize': 'fit'}},
#       'source_status_id': 1586468156788412420,
#       'source_status_id_str': '1586468156788412420',
#       'source_user_id': 1212685850095452160,
#       'source_user_id_str': '1212685850095452160'},
#      {'id': 1586468145786765313,
#       'id_str': '1586468145786765313',
#       'indices': [57, 80],
#       'media_url': 'http://pbs.twimg.com/media/FgREX4UXwAEz7cC.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FgREX4UXwAEz7cC.jpg',
#       'url': 'https://t.co/SXmSuhA2hR',
#       'display_url': 'pic.twitter.com/SXmSuhA2hR',
#       'expanded_url': 'https://twitter.com/pusholder/status/1586468156788412420/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1600, 'h': 1198, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 509, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 899, 'resize': 'fit'}},
#       'source_status_id': 1586468156788412420,
#       'source_status_id_str': '1586468156788412420',
#       'source_user_id': 1212685850095452160,
#       'source_user_id_str': '1212685850095452160'}]},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 776345374554456064,
#     'id_str': '776345374554456064',
#     'name': 'denef',
#     'screen_name': 'kuslarindili',
#     'location': '',
#     'description': 'Aдыгэ',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 226,
#     'friends_count': 659,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 15 09:02:15 +0000 2016',
#     'favourites_count': 151,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 906,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1573941996280025088/5Abc1rPn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1573941996280025088/5Abc1rPn_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 21:20:58 +0000 2022',
#     'id': 1586468156788412420,
#     'id_str': '1586468156788412420',
#     'text': "İstanbul'da 29 Ekim Cumhuriyet Bayramı 🇹🇷 https://t.co/SXmSuhA2hR",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1586468145803526145,
#        'id_str': '1586468145803526145',
#        'indices': [42, 65],
#        'media_url': 'http://pbs.twimg.com/media/FgREX4YXgAEOw2j.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FgREX4YXgAEOw2j.jpg',
#        'url': 'https://t.co/SXmSuhA2hR',
#        'display_url': 'pic.twitter.com/SXmSuhA2hR',
#        'expanded_url': 'https://twitter.com/pusholder/status/1586468156788412420/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1600, 'h': 1198, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 509, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 899, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1586468145803526145,
#        'id_str': '1586468145803526145',
#        'indices': [42, 65],
#        'media_url': 'http://pbs.twimg.com/media/FgREX4YXgAEOw2j.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FgREX4YXgAEOw2j.jpg',
#        'url': 'https://t.co/SXmSuhA2hR',
#        'display_url': 'pic.twitter.com/SXmSuhA2hR',
#        'expanded_url': 'https://twitter.com/pusholder/status/1586468156788412420/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1600, 'h': 1198, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 509, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 899, 'resize': 'fit'}}},
#       {'id': 1586468145786765313,
#        'id_str': '1586468145786765313',
#        'indices': [42, 65],
#        'media_url': 'http://pbs.twimg.com/media/FgREX4UXwAEz7cC.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FgREX4UXwAEz7cC.jpg',
#        'url': 'https://t.co/SXmSuhA2hR',
#        'display_url': 'pic.twitter.com/SXmSuhA2hR',
#        'expanded_url': 'https://twitter.com/pusholder/status/1586468156788412420/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1600, 'h': 1198, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 509, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 899, 'resize': 'fit'}}}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1212685850095452160,
#      'id_str': '1212685850095452160',
#      'name': 'Pusholder',
#      'screen_name': 'pusholder',
#      'location': 'Türkiye',
#      'description': 'Yeni Nesil Dijital Medya | Gündemi tek tweet ile takip etmek için bildirimleri açabilirsiniz. Spor Kanalı: @pusholdersport',
#      'url': 'https://t.co/Kr12WmVwN5',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Kr12WmVwN5',
#          'expanded_url': 'http://ads.pusholder.com',
#          'display_url': 'ads.pusholder.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1405477,
#      'friends_count': 64,
#      'listed_count': 1101,
#      'created_at': 'Thu Jan 02 10:45:01 +0000 2020',
#      'favourites_count': 12,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 29248,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1464706341927325699/8YX-8F___normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1464706341927325699/8YX-8F___normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1212685850095452160/1649508611',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 644,
#     'favorite_count': 27547,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 644,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'tr'},
# ...
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 18:03:42 +0000 2022',
#     'id': 1586418515346657281,
#     'id_str': '1586418515346657281',
#     'text': 'İletişim Başkanlığı’nın 29 Ekim’e özel yaptığı gösteriler Aslan Değirmenci’nin talimatıyla Burak Doğan tarafından b… https://t.co/RcpFOn3K13',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/RcpFOn3K13',
#        'expanded_url': 'https://twitter.com/i/web/status/1586418515346657281',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1188018623404806144,
#      'id_str': '1188018623404806144',
#      'name': 'Bu TT Kim Yaptı ?',
#      'screen_name': 'BuTTKimYapti',
#      'location': 'Türkiye',
#      'description': "Bu Trend Topic'i kim yaptı ya ? Diyorsanız, işte cevap burada",
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3937,
#      'friends_count': 3876,
#      'listed_count': 0,
#      'created_at': 'Sat Oct 26 09:05:07 +0000 2019',
#      'favourites_count': 754,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 272,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1249337778921443329/V_1leCd9_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249337778921443329/V_1leCd9_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1188018623404806144/1586700313',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 682,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Sun Oct 30 06:55:43 +0000 2022',
#    'id': 1586612797164687360,
#    'id_str': '1586612797164687360',
#    'text': 'RT @muratbalac: 29 Ekim Cumhuriyet bayramımızı kutlar, başta Cumhuriyetimizin kurucusu Gazi Mustafa Kemal Atatürk ve silah arkadaşları  olm…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'muratbalac',
#       'name': 'Muratbalaç♥️🇹🇷🤍58',
#       'id': 1073992750062821377,
#       'id_str': '1073992750062821377',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 889557057841614848,
#     'id_str': '889557057841614848',
#     'name': 'TÜRKİYE CANDIR🇹🇷Rt',
#     'screen_name': 'TimurCandir',
#     'location': 'Türkiye 🇹🇷',
#     'description': 'Ana hesap @AdnanTimur',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1729,
#     'friends_count': 1745,
#     'listed_count': 1,
#     'created_at': 'Mon Jul 24 18:45:04 +0000 2017',
#     'favourites_count': 12872,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 10030,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/977945659952287749/NlDEy6tH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/977945659952287749/NlDEy6tH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/889557057841614848/1663333660',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 05:13:10 +0000 2022',
#     'id': 1586224603932037120,
#     'id_str': '1586224603932037120',
#     'text': '29 Ekim Cumhuriyet bayramımızı kutlar, başta Cumhuriyetimizin kurucusu Gazi Mustafa Kemal Atatürk ve silah arkadaşl… https://t.co/J7WIH7u12l',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/J7WIH7u12l',
#        'expanded_url': 'https://twitter.com/i/web/status/1586224603932037120',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1073992750062821377,
#      'id_str': '1073992750062821377',
#      'name': 'Muratbalaç♥️🇹🇷🤍58',
#      'screen_name': 'muratbalac',
#      'location': 'İstanbul, Türkiye',
#      'description': 'GAZİOSMANPAŞA Karayolları mahallesi ak parti şehit ve gazi  başkanı Ve TANITIM MEDYA BAŞKAN YARDIMCISI🇹🇷🇹🇷🇹🇷',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 10360,
#      'friends_count': 11387,
#      'listed_count': 0,
#      'created_at': 'Sat Dec 15 17:26:40 +0000 2018',
#      'favourites_count': 61018,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 59118,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1578114404540981248/eoZx0H3b_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1578114404540981248/eoZx0H3b_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1073992750062821377/1644778366',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 48,
#     'favorite_count': 55,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 48,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Sun Oct 30 06:55:42 +0000 2022',
#    'id': 1586612793935122433,
#    'id_str': '1586612793935122433',
#    'text': 'RT @hakki_alkan: Yaşasın Cumhuriyet, yaşasın Türk mühendisleri. 29 Ekim Cumhuriyet Bayramı için en güzel hediye #Togg oldu. Gemlik Kampüsü’…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Togg', 'indices': [112, 117]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'hakki_alkan',
#       'name': 'Hakkı Alkan',
#       'id': 28147896,
#       'id_str': '28147896',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1586310203032715264,
#     'id_str': '1586310203032715264',
#     'name': 'Barış',
#     'screen_name': 'Bar52314371S',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1,
#     'friends_count': 14,
#     'listed_count': 0,
#     'created_at': 'Sat Oct 29 10:53:55 +0000 2022',
#     'favourites_count': 113,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 98,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Oct 29 15:45:29 +0000 2022',
#     'id': 1586383729756639233,
#     'id_str': '1586383729756639233',
#     'text': 'Yaşasın Cumhuriyet, yaşasın Türk mühendisleri. 29 Ekim Cumhuriyet Bayramı için en güzel hediye #Togg oldu. Gemlik K… https://t.co/PoiAdF0DI0',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Togg', 'indices': [95, 100]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/PoiAdF0DI0',
#        'expanded_url': 'https://twitter.com/i/web/status/1586383729756639233',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 28147896,
#      'id_str': '28147896',
#      'name': 'Hakkı Alkan',
#      'screen_name': 'hakki_alkan',
#      'location': 'San Francisco, CA',
#      'description': 'Tech Influencer \nFounder of @shiftdeletenet \n📩 hakkialkan@socialand.com.tr \n#teknoloji #technology \n📸 https://t.co/dNJ4yLKziY',
#      'url': 'https://t.co/puk9HpecZW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/puk9HpecZW',
#          'expanded_url': 'http://shiftdelete.net/',
#          'display_url': 'shiftdelete.net',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/dNJ4yLKziY',
#          'expanded_url': 'http://instagram.com/hakki_alkan/',
#          'display_url': 'instagram.com/hakki_alkan/',
#          'indices': [102, 125]}]}},
#      'protected': False,
#      'followers_count': 140272,
#      'friends_count': 876,
#      'listed_count': 272,
#      'created_at': 'Wed Apr 01 17:21:22 +0000 2009',
#      'favourites_count': 12176,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 43273,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '0099B9',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1235249041551831041/kBN164mA_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235249041551831041/kBN164mA_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28147896/1660200404',
#      'profile_link_color': '0099B9',
#      'profile_sidebar_border_color': '5ED4DC',
#      'profile_sidebar_fill_color': '95E8EC',
#      'profile_text_color': '3C3940',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'regular',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '13493c799a155001',
#      'url': 'https://api.twitter.com/1.1/geo/id/13493c799a155001.json',
#      'place_type': 'poi',
#      'name': 'TOGG Türkiye’nin Otomobili Girişim Grubu',
#      'full_name': 'TOGG Türkiye’nin Otomobili Girişim Grubu',
#      'country_code': 'TR',
#      'country': 'Turkey',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[29.076868, 40.394563],
#         [29.076868, 40.394563],
#         [29.076868, 40.394563],
#         [29.076868, 40.394563]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 814,
#     'favorite_count': 8741,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'tr'},
#    'is_quote_status': False,
#    'retweet_count': 814,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'}],
#  'search_metadata': {'completed_in': 0.131,
#   'max_id': 1586613237147398144,
#   'max_id_str': '1586613237147398144',
#   'next_results': '?max_id=1586612793935122432&q=29%20Ekim&count=100&include_entities=1',
#   'query': '29+Ekim',
#   'refresh_url': '?since_id=1586613237147398144&q=29%20Ekim&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
all_items=results["statuses"]  #Json formatta dönen dataları dataframe e çevirme işlemi

# %%
import pandas as pd

# %%
df=pd.DataFrame(all_items)

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Oct 30 06:57:28 +0000 2022  1586613237147398144  1586613237147398144
# 1  Sun Oct 30 06:57:27 +0000 2022  1586613234337030145  1586613234337030145
# 2  Sun Oct 30 06:57:24 +0000 2022  1586613219438858240  1586613219438858240
# 3  Sun Oct 30 06:57:23 +0000 2022  1586613218377596930  1586613218377596930
# 4  Sun Oct 30 06:57:23 +0000 2022  1586613218365030400  1586613218365030400
#
#                                                 text  truncated  \
# 0  RT @avmustafakose: Türkiye Cumhuriyeti 99 yaşı...      False
# 1  RT @liberaLDP: Tüm halkımızın 29 Ekim Cumhuriy...      False
# 2  RT @tr_hbr: 🔥 TRT spikerinin 29 Ekim mesajı ce...      False
# 3  Trabzon da Trabzonlu Trabzonspor  lu vatandaşl...       True
# 4  RT @tcbestepe: Türkiye Cumhuriyeti Cumhurbaşka...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [{'text': '29EkimCumhiyetBayramı'...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'result_type': 'recent', 'iso_language_code':...
# 1  {'result_type': 'recent', 'iso_language_code':...
# 2  {'result_type': 'recent', 'iso_language_code':...
# 3  {'result_type': 'recent', 'iso_language_code':...
# 4  {'result_type': 'recent', 'iso_language_code':...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="http://twitter.com/download/android" ...                    NaN
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="http://twitter.com/download/android" ...                    NaN
# 4  <a href="http://twitter.com/download/android" ...                    NaN
#
#   in_reply_to_status_id_str  ...  is_quote_status retweet_count  \
# 0                      None  ...            False            42
# 1                      None  ...            False            41
# 2                      None  ...            False             3
# 3                      None  ...            False             0
# 4                      None  ...             True           554
#
#   favorite_count favorited retweeted lang possibly_sensitive quoted_status_id  \
# 0              0     False     False   tr                NaN              NaN
# 1              0     False     False   tr                NaN              NaN
# 2              0     False     False   tr                NaN              NaN
# 3              0     False     False   tr              False              NaN
# 4              0     False     False   tr                NaN     1.586246e+18
#
#   quoted_status_id_str  extended_entities
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4  1586245759720214530                NaN
#
# [5 rows x 29 columns]

# %%
users=pd.DataFrame(d["user"] for d in results["statuses"]) #Kullanıcı bilgilerin tekrar düzenlenmesi

# %%
users.head()
# Out:
#                     id               id_str               name  \
# 0           1476852564           1476852564       HAYATİ DEMİR
# 1  1548889838472073217  1548889838472073217         Eren Gaert
# 2            391612293            391612293                hiç
# 3  1492502911737380865  1492502911737380865           SBalcı29
# 4           3027787005           3027787005  Selçuk Şakalar 🇹🇷
#
#        screen_name location  \
# 0        kaman4006
# 1     ErenMathers0
# 2        na_mevcut
# 3         SBALCI29
# 4  SelcukSakalar46
#
#                                          description   url  \
# 0                                                     None
# 1                                              🗽🇺🇸🇹🇷  None
# 2  Varlığımdan intihâsızlık terennüm eyliyen Bezm...  None
# 3                                           ❤💙⭐ ⚖️ 🦂  None
# 4  YOLUMUZ AK DAVAMIZ HAK..\n#instagramhesabımyoktur  None
#
#                         entities  protected  followers_count  ...  \
# 0  {'description': {'urls': []}}      False              368  ...
# 1  {'description': {'urls': []}}      False               27  ...
# 2  {'description': {'urls': []}}      False              625  ...
# 3  {'description': {'urls': []}}      False             5810  ...
# 4  {'description': {'urls': []}}      False              861  ...
#
#    profile_use_background_image  has_extended_profile default_profile  \
# 0                          True                  True            True
# 1                          True                  True            True
# 2                          True                 False            True
# 3                          True                  True            True
# 4                          True                 False            True
#
#    default_profile_image following follow_request_sent  notifications  \
# 0                  False      None                None           None
# 1                  False      None                None           None
# 2                  False      None                None           None
# 3                  False      None                None           None
# 4                  False      None                None           None
#
#    translator_type  withheld_in_countries  \
# 0             none                     []
# 1             none                     []
# 2             none                     []
# 3             none                     []
# 4             none                     []
#
#                                   profile_banner_url
# 0                                                NaN
# 1  https://pbs.twimg.com/profile_banners/15488898...
# 2                                                NaN
# 3  https://pbs.twimg.com/profile_banners/14925029...
# 4  https://pbs.twimg.com/profile_banners/30277870...
#
# [5 rows x 43 columns]

# %%
tdf=df.merge(users,left_index=True,right_index=True)

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 72 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   created_at_x                        100 non-null    object
#  1   id_x                                100 non-null    int64
#  2   id_str_x                            100 non-null    object
#  3   text                                100 non-null    object
#  4   truncated                           100 non-null    bool
#  5   entities_x                          100 non-null    object
#  6   metadata                            100 non-null    object
#  7   source                              100 non-null    object
#  8   in_reply_to_status_id               3 non-null      float64
#  9   in_reply_to_status_id_str           3 non-null      object
#  10  in_reply_to_user_id                 3 non-null      float64
#  11  in_reply_to_user_id_str             3 non-null      object
#  12  in_reply_to_screen_name             3 non-null      object
#  13  user                                100 non-null    object
#  14  geo                                 0 non-null      object
#  15  coordinates                         0 non-null      object
#  16  place                               2 non-null      object
#  17  contributors                        0 non-null      object
#  18  retweeted_status                    90 non-null     object
#  19  is_quote_status                     100 non-null    bool
#  20  retweet_count                       100 non-null    int64
#  21  favorite_count                      100 non-null    int64
#  22  favorited                           100 non-null    bool
#  23  retweeted                           100 non-null    bool
#  24  lang_x                              100 non-null    object
#  25  possibly_sensitive                  28 non-null     object
#  26  quoted_status_id                    2 non-null      float64
#  27  quoted_status_id_str                2 non-null      object
#  28  extended_entities                   22 non-null     object
#  29  id_y                                100 non-null    int64
#  30  id_str_y                            100 non-null    object
#  31  name                                100 non-null    object
#  32  screen_name                         100 non-null    object
#  33  location                            100 non-null    object
#  34  description                         100 non-null    object
#  35  url                                 8 non-null      object
#  36  entities_y                          100 non-null    object
#  37  protected                           100 non-null    bool
#  38  followers_count                     100 non-null    int64
#  39  friends_count                       100 non-null    int64
#  40  listed_count                        100 non-null    int64
#  41  created_at_y                        100 non-null    object
#  42  favourites_count                    100 non-null    int64
#  43  utc_offset                          0 non-null      object
#  44  time_zone                           0 non-null      object
#  45  geo_enabled                         100 non-null    bool
#  46  verified                            100 non-null    bool
#  47  statuses_count                      100 non-null    int64
#  48  lang_y                              0 non-null      object
#  49  contributors_enabled                100 non-null    bool
#  50  is_translator                       100 non-null    bool
#  51  is_translation_enabled              100 non-null    bool
#  52  profile_background_color            100 non-null    object
#  53  profile_background_image_url        31 non-null     object
#  54  profile_background_image_url_https  31 non-null     object
#  55  profile_background_tile             100 non-null    bool
#  56  profile_image_url                   100 non-null    object
#  57  profile_image_url_https             100 non-null    object
#  58  profile_link_color                  100 non-null    object
#  59  profile_sidebar_border_color        100 non-null    object
#  60  profile_sidebar_fill_color          100 non-null    object
#  61  profile_text_color                  100 non-null    object
#  62  profile_use_background_image        100 non-null    bool
#  63  has_extended_profile                100 non-null    bool
#  64  default_profile                     100 non-null    bool
#  65  default_profile_image               100 non-null    bool
#  66  following                           0 non-null      object
#  67  follow_request_sent                 0 non-null      object
#  68  notifications                       0 non-null      object
#  69  translator_type                     100 non-null    object
#  70  withheld_in_countries               100 non-null    object
#  71  profile_banner_url                  61 non-null     object
# dtypes: bool(15), float64(3), int64(9), object(45)
# memory usage: 46.1+ KB

# %%
tdf.location.value_counts().plot(kind="bar",figsize=(10,6))
# Out:
# <AxesSubplot:>
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127481 (\N{REGIONAL INDICATOR SYMBOL LETTER T}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127479 (\N{REGIONAL INDICATOR SYMBOL LETTER R}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Sentiment Analysis olumlu-olumsuz

# %%
from textblob import TextBlob

# %%
TextBlob("Love").polarity #olumlu ploartiy değeri -1 ile +1 arasında değer alır. Sıfırın üzerinde ise olumlu
# Out:
# 0.5

# %%
TextBlob("Hate").polarity #olumsuz
# Out:
# -0.8

# %%
TextBlob("the best").polarity
# Out:
# 1.0

# %%
TextBlob("the best").sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
def detect_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
df2=tdf[["text"]]

# %%
df2.head()
# Out:
#                                                 text
# 0  RT @avmustafakose: Türkiye Cumhuriyeti 99 yaşı...
# 1  RT @liberaLDP: Tüm halkımızın 29 Ekim Cumhuriy...
# 2  RT @tr_hbr: 🔥 TRT spikerinin 29 Ekim mesajı ce...
# 3  Trabzon da Trabzonlu Trabzonspor  lu vatandaşl...
# 4  RT @tcbestepe: Türkiye Cumhuriyeti Cumhurbaşka...

# %%
df2["sentiment"]=df2["text"].apply(detect_sentiment)
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_17144\1909004749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sentiment"]=df2["text"].apply(detect_sentiment)

# %%
df2.tail()
# Out:
#                                                  text  sentiment
# 95  RT @reise_sevda: Mühim bir detayı sizinle payl...        0.0
# 96  RT @BuTTKimYapti: İletişim Başkanlığı’nın 29 E...        0.0
# 97  RT @BuTTKimYapti: İletişim Başkanlığı’nın 29 E...        0.0
# 98  RT @muratbalac: 29 Ekim Cumhuriyet bayramımızı...        0.0
# 99  RT @hakki_alkan: Yaşasın Cumhuriyet, yaşasın T...        0.0

# %%
df2.sentiment.value_counts()
# Out:
# 0.0    98
# 0.6     2
# Name: sentiment, dtype: int64

# %%
df2["text"]=df2["text"].str.lower()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_17144\1934567259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.lower()

# %%
df2["text"]=df2["text"].str.replace('[^\w\s]','')
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_17144\2430991166.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["text"]=df2["text"].str.replace('[^\w\s]','')
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_17144\2430991166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace('[^\w\s]','')

# %%
df2["text"]=df2["text"].str.replace('\d+','')
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_17144\1091199844.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["text"]=df2["text"].str.replace('\d+','')
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_17144\1091199844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace('\d+','')

# %%
df2["text"]=df2["text"].str.replace('\n','').replace('\r','')
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_17144\2655869773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["text"]=df2["text"].str.replace('\n','').replace('\r','')

# %%
from wordcloud import STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def wc(data,bgcolor):
    plt.figure(figsize=(10,10))
    mask=np.array(Image.open("togg.png"))
    wc=WordCloud(background_color=bgcolor,stopwords=STOPWORDS,mask=mask)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis("off")

# %%
wc(df2.text,'white')

# %%
# 1 positive 2 negative 0 notr
def sentiment2(sent):
    if sent<-0.2:
        return 3
    elif sent>0.2:
        return 1
    else:
        return 0

# %%
 df2["sent"]=df2["sentiment"].apply(sentiment2)
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_17144\442396478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sent"]=df2["sentiment"].apply(sentiment2)

# %%
df2.head()
# Out:
#                                                 text  sentiment  sent
# 0  rt avmustafakose türkiye cumhuriyeti  yaşındac...        0.0     0
# 1  rt liberaldp tüm halkımızın  ekim cumhuriyet b...        0.0     0
# 2  rt tr_hbr  trt spikerinin  ekim mesajı cezasız...        0.0     0
# 3  trabzon da trabzonlu trabzonspor  lu vatandaşl...        0.0     0
# 4  rt tcbestepe türkiye cumhuriyeti cumhurbaşkanl...        0.0     0

# %%
import seaborn as sns

# %%
sns.countplot(x=df2.sent)
# Out:
# <AxesSubplot:xlabel='sent', ylabel='count'>

# %%
x=df2["text"]
y=df2.sent

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
vect=CountVectorizer(stop_words="english")

# %%
x=vect.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.15)

# %%
mb=MultinomialNB()

# %%
tahmin=mb.fit(x_train,y_train).predict(x_test)

# %%
accuracy_score(tahmin,y_test) # verimiz 100 satirlik
# Out:
# 0.8666666666666667
