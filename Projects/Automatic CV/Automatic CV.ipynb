# %%
#pip install cvlib

# %%
import cv2
import matplotlib.pyplot as plt
from cvlib.object_detection import draw_bbox
import cvlib

# %%
img=cv2.imread("cars.jpg")

# %%
img
# Out:
# array([[[ 18,  23,  22],
#         [ 11,  16,  15],
#         [  5,  10,   9],
#         ...,
#         [ 27,  26,  30],
#         [ 27,  26,  30],
#         [ 28,  27,  31]],
#
#        [[ 18,  23,  22],
#         [ 10,  15,  14],
#         [  5,  10,   9],
#         ...,
#         [ 27,  26,  30],
#         [ 27,  26,  30],
#         [ 28,  27,  31]],
#
#        [[ 19,  21,  21],
#         [ 12,  14,  14],
#         [  6,   8,   8],
#         ...,
#         [ 27,  26,  30],
#         [ 27,  26,  30],
#         [ 28,  27,  31]],
#
#        ...,
#
#        [[153, 158, 161],
#         [153, 158, 161],
#         [154, 159, 162],
#         ...,
#         [141, 144, 148],
#         [142, 145, 149],
#         [143, 146, 150]],
#
#        [[151, 156, 159],
#         [154, 159, 162],
#         [157, 162, 165],
#         ...,
#         [142, 145, 149],
#         [143, 146, 150],
#         [144, 147, 151]],
#
#        [[151, 156, 159],
#         [154, 159, 162],
#         [157, 162, 165],
# ...

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)
# Out:
# ...
#   0% |                                                                        |
# ...
#  99% |####################################################################### |
# ...
# 100% |                                                                        |

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(15,15))
plt.imshow(output)

# %%
t=0
for i in label:
    if i=="car":
        t=t+1
print(str(t)+" adet araba var")
# Out:
# 11 adet araba var

# %%
img2=cv2.imread("g20.jpg")

# %%
plt.imshow(img2)

# %%
box,label,count=cvlib.detect_common_objects(img2)
output=draw_bbox(img2,box,label,count)

# %%
plt.figure(figsize=(15,15))
plt.imshow(output)

# %%
t=0
for i in label:
    if i=="person":
        t=t+1
print(str(t)+" kişi var")
# Out:
# 14 kişi var

# %%
img3=cv2.imread("tomato.jpg")

# %%
plt.imshow(img3)

# %%
box,label,count=cvlib.detect_common_objects(img3)

# %%
output=draw_bbox(img3,box,label,count)

# %%
plt.figure(figsize=(15,15))
plt.imshow(output)
