# %%
import pandas as pd   #pandas paketi import edildi

# %%
df1=pd.read_csv("client_list.csv") #dosya okuma ve df1 değişkenine atama

# %%
df2=pd.read_csv("client_list.table")   #dosya okuma ve df2 değişkenine atama

# %%
df3=pd.read_csv("client_list.txt")   #dosya okuma ve df3 değişkenine atama

# %%
df3=pd.read_csv("client_list.csv", header=None)   #df3 değişkeninde ki dosya okuma ve headerları kaldırma

# %%
df3    #Sütun adları numaralandırılmıştır.
# Out:
#              0          1       2    3           4          5
# 0   first_name  LAST_NAME  gender  Age  Hair_COLOR  eye_Color
# 1     Jennifer      Jones       F   27       black      brown
# 2        Jaime    Roberts       M   32       brown      hazel
# 3      Michael    Johnson       M   55         red      green
# 4         Mary      Adams       F   42      blonde       blue
# 5       Robert   Phillips       M   37      blonde      brown
# 6       Thomas      Moore       M   60       brown       blue
# 7      Natalie     Potter       F   21       brown      green
# 8       Brenda      Jones       F   18      blonde      brown
# 9      Michael      Smith       M   58       brown      brown
# 10    Jennifer      Smith       F   36       black      brown
# 11     Michael      Smith       M   37       black      hazel
# 12     Jessica     Rabbit       F   19       black       blue
# 13       Molly     Bryant       F   21       brown       blue
# ...

# %%
df=pd.read_csv("client_list.csv")   #df değişleni tekrar dosya okuma işlemi yapıldı

# %%
df.columns.str.upper() #Sütun adları büyük harflere çevrildi
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'GENDER', 'AGE', 'HAIR_COLOR', 'EYE_COLOR'], dtype='object')

# %%
pd.read_csv("client_list_practice.csv")
# Out:
#    FIRST_NAME LAST_NAME GENDER   AGE HAIR_COLOR EYE_COLOR
# 0    Jennifer     Jones      F  27.0      black     brown
# 1       Jaime   Roberts      M  32.0      brown     hazel
# 2     Michael   Johnson      M  55.0        red     green
# 3        Mary       NaN      F  42.0     blonde       NaN
# 4         NaN  Phillips      M  37.0        NaN     brown
# 5      Thomas     Moore      M  60.0      brown      blue
# 6     Natalie    Potter      F   NaN      brown     green
# 7      Brenda     Jones      F   NaN        NaN     brown
# 8     Michael     Smith    NaN  58.0      brown     brown
# 9    Jennifer     Smith      F  36.0      black     brown
# 10    Michael     Smith      M  37.0      black     hazel
# 11    Jessica       NaN      F  19.0      black      blue
# 12      Molly    Bryant      F  21.0      brown      blue
# 13      Jaime  Anderson      F  46.0      brown     green

# %%
pd.read_csv("client_list_practice.csv",usecols = ['LAST_NAME','GENDER','HAIR_COLOR']) # Dosyadan FIRST_NAME, AGE ve EYE_COLOR alanları çıkarıldı
# Out:
#    LAST_NAME GENDER HAIR_COLOR
# 0      Jones      F      black
# 1    Roberts      M      brown
# 2    Johnson      M        red
# 3        NaN      F     blonde
# 4   Phillips      M        NaN
# 5      Moore      M      brown
# 6     Potter      F      brown
# 7      Jones      F        NaN
# 8      Smith    NaN      brown
# 9      Smith      F      black
# 10     Smith      M      black
# 11       NaN      F      black
# 12    Bryant      F      brown
# 13  Anderson      F      brown

# %%
df  #df dosyasına bakıyoruz
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 0    Jennifer     Jones      F   27      black     brown
# 1       Jaime   Roberts      M   32      brown     hazel
# 2     Michael   Johnson      M   55        red     green
# 3        Mary     Adams      F   42     blonde      blue
# 4      Robert  Phillips      M   37     blonde     brown
# 5      Thomas     Moore      M   60      brown      blue
# 6     Natalie    Potter      F   21      brown     green
# 7      Brenda     Jones      F   18     blonde     brown
# 8     Michael     Smith      M   58      brown     brown
# 9    Jennifer     Smith      F   36      black     brown
# 10    Michael     Smith      M   37      black     hazel
# 11    Jessica    Rabbit      F   19      black      blue
# 12      Molly    Bryant      F   21      brown      blue
# 13      Jaime  Anderson      F   46      brown     green

# %%
df.iloc[5:11]  # 5 ve 11 inci satır aralığındaki verileri çekiyoruz
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 5      Thomas     Moore      M   60      brown      blue
# 6     Natalie    Potter      F   21      brown     green
# 7      Brenda     Jones      F   18     blonde     brown
# 8     Michael     Smith      M   58      brown     brown
# 9    Jennifer     Smith      F   36      black     brown
# 10    Michael     Smith      M   37      black     hazel

# %%
df=pd.read_csv("client_list.csv",usecols = ['LAST_NAME','Age','Hair_COLOR'])

# %%
df  #belirtilen sütunlar seçildi
# Out:
#    LAST_NAME  Age Hair_COLOR
# 0      Jones   27      black
# 1    Roberts   32      brown
# 2    Johnson   55        red
# 3      Adams   42     blonde
# 4   Phillips   37     blonde
# 5      Moore   60      brown
# 6     Potter   21      brown
# 7      Jones   18     blonde
# 8      Smith   58      brown
# 9      Smith   36      black
# 10     Smith   37      black
# 11    Rabbit   19      black
# 12    Bryant   21      brown
# 13  Anderson   46      brown

# %%
df=pd.read_csv("client_list.csv",usecols = ['LAST_NAME','Age','Hair_COLOR'],iloc[5:11])
# Out:
#   Input In [47]
#     df=pd.read_csv("client_list.csv",usecols = ['LAST_NAME','Age','Hair_COLOR'],iloc[5:11])
#                                                                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
df
# Out:
#    LAST_NAME   Age Hair_COLOR
# 0        NaN   NaN        NaN
# 1        NaN   NaN        NaN
# 2        NaN   NaN        NaN
# 3        NaN   NaN        NaN
# 4        NaN   NaN        NaN
# 5      Moore  60.0      brown
# 6     Potter  21.0      brown
# 7      Jones  18.0     blonde
# 8      Smith  58.0      brown
# 9      Smith  36.0      black
# 10     Smith  37.0      black
# 11       NaN   NaN        NaN
# 12       NaN   NaN        NaN
# 13       NaN   NaN        NaN

# %%
df[(df["LAST_NAME"]=="Smith")]  #Soyadı Smith olanlar
# Out:
#    LAST_NAME   Age Hair_COLOR
# 8      Smith  58.0      brown
# 9      Smith  36.0      black
# 10     Smith  37.0      black

# %%
df[(df["Hair_COLOR"]!="black")]  #Saç rengi siyah olmayanlar
# Out:
#    LAST_NAME   Age Hair_COLOR
# 0        NaN   NaN        NaN
# 1        NaN   NaN        NaN
# 2        NaN   NaN        NaN
# 3        NaN   NaN        NaN
# 4        NaN   NaN        NaN
# 5      Moore  60.0      brown
# 6     Potter  21.0      brown
# 7      Jones  18.0     blonde
# 8      Smith  58.0      brown
# 11       NaN   NaN        NaN
# 12       NaN   NaN        NaN
# 13       NaN   NaN        NaN

# %%
df['Hair_COLOR']=df["Hair_COLOR"].replace({'red':'ginger'})    #df['Status'] = df['Status'].replace({'P': 'A'})

# %%
df
# Out:
#    LAST_NAME   Age Hair_COLOR
# 0        NaN   NaN        NaN
# 1        NaN   NaN        NaN
# 2        NaN   NaN        NaN
# 3        NaN   NaN        NaN
# 4        NaN   NaN        NaN
# 5      Moore  60.0      brown
# 6     Potter  21.0      brown
# 7      Jones  18.0     blonde
# 8      Smith  58.0      brown
# 9      Smith  36.0      black
# 10     Smith  37.0      black
# 11       NaN   NaN        NaN
# 12       NaN   NaN        NaN
# 13       NaN   NaN        NaN

# %%
df=pd.read_csv("client_list.csv")

# %%
df[(df["Age"]>30) & (df["gender"]=="F") ] #30 yaşından büyük kadınlar
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 3        Mary     Adams      F   42     blonde      blue
# 9    Jennifer     Smith      F   36      black     brown
# 13      Jaime  Anderson      F   46      brown     green

# %%
df[(df["Age"]>30) & (df["gender"]=="F")]
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 3        Mary     Adams      F   42     blonde      blue
# 9    Jennifer     Smith      F   36      black     brown
# 13      Jaime  Anderson      F   46      brown     green

# %%
hair=df['Hair_COLOR']
eye=df['eye_Color']

# %%
df[(df["Age"]>30) & (df["gender"]=="F"),(df['hair', 'eye'])]  #30 yaşından büyük kadınların saç ve göz rekleri bilgisi
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('hair', 'eye')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.describe()
# Out:
#              Age
# count  14.000000
# mean   36.357143
# std    14.457402
# min    18.000000
# 25%    22.500000
# 50%    36.500000
# 75%    45.000000
# max    60.000000

# %%
df[(df["Age"]>25) & (df["gender"]=="F")] #25 yaşından büyük kadınlar
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 0    Jennifer     Jones      F   27      black     brown
# 3        Mary     Adams      F   42     blonde      blue
# 9    Jennifer     Smith      F   36      black     brown
# 13      Jaime  Anderson      F   46      brown     green

# %%
sac=df['Hair_COLOR'].unique()
goz=df['eye_Color'].unique()

# %%
 goz
# Out:
# array(['brown', 'hazel', 'green', 'blue'], dtype=object)

# %%
sac
# Out:
# array(['black', 'brown', 'red', 'blonde'], dtype=object)

# %%
df[(df["Age"]>25) & (df["gender"]=="F")]
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color
# 0    Jennifer     Jones      F   27      black     brown
# 3        Mary     Adams      F   42     blonde      blue
# 9    Jennifer     Smith      F   36      black     brown
# 13      Jaime  Anderson      F   46      brown     green

# %%
df4=pd.read_csv('client_list.csv')
df5=pd.read_csv('customer_id_list.csv')

# %%
clients=pd.merge(df4,df5)  #İki farklı dosyadan birleştirme işlemi yaptık

# %%
clients
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color  CUSTOMER_ID  \
# 0    Jennifer     Jones      F   27      black     brown            1
# 1    Jennifer     Jones      F   27      black     brown            8
# 2      Brenda     Jones      F   18     blonde     brown            1
# 3      Brenda     Jones      F   18     blonde     brown            8
# 4       Jaime   Roberts      M   32      brown     hazel            2
# 5     Michael   Johnson      M   55        red     green            3
# 6        Mary     Adams      F   42     blonde      blue            4
# 7      Robert  Phillips      M   37     blonde     brown            5
# 8      Thomas     Moore      M   60      brown      blue            6
# 9     Natalie    Potter      F   21      brown     green            7
# 10    Michael     Smith      M   58      brown     brown            9
# 11    Michael     Smith      M   58      brown     brown           10
# ...

# %%
df6=pd.read_csv('purchase_log.csv')

# %%
detailed_sales=pd.merge(clients,df6) #Diğer tablo ile birleştirme işlemi

# %%
detailed_sales.groupby('PRICE');

# %%
detailed_sales
# Out:
#    first_name LAST_NAME gender  Age Hair_COLOR eye_Color  CUSTOMER_ID  \
# 0    Jennifer     Jones      F   27      black     brown            1
# 1      Brenda     Jones      F   18     blonde     brown            1
# 2       Jaime   Roberts      M   32      brown     hazel            2
# 3        Mary     Adams      F   42     blonde      blue            4
# 4      Thomas     Moore      M   60      brown      blue            6
# 5     Michael     Smith      M   58      brown     brown            9
# 6     Michael     Smith      M   58      brown     brown            9
# 7    Jennifer     Smith      F   36      black     brown            9
# 8    Jennifer     Smith      F   36      black     brown            9
# 9     Michael     Smith      M   37      black     hazel            9
# 10    Michael     Smith      M   37      black     hazel            9
# 11    Michael     Smith      M   58      brown     brown           11
# ...

# %%
data_grp=detailed_sales.groupby('PRICE')

# %%
data_grp.first()
# Out:
#        first_name LAST_NAME gender  Age Hair_COLOR eye_Color  CUSTOMER_ID  \
# PRICE
# 3.99       Thomas     Moore      M   60      brown      blue            6
# 12.99    Jennifer     Jones      F   27      black     brown            1
# 14.99       Jaime  Anderson      F   46      brown     green           14
# 29.99     Michael     Smith      M   58      brown     brown            9
# 39.99        Mary     Adams      F   42     blonde      blue            4
# 50.00       Jaime   Roberts      M   32      brown     hazel            2
# 109.99    Michael     Smith      M   58      brown     brown           11
# 199.99    Michael     Smith      M   58      brown     brown            9
#
#        FIRST_NAME GENDER  AGE        DATE    SKU           ITEM_DESCRIPTION
# PRICE
# 3.99       Thomas      M   60  09/13/2014  22495              birthday card
# 12.99    Jennifer      F   27  01/01/2015  39490                    aspirin
# ...

# %%
data_grp.first().sample() #Buraya bakılacak
# Out:
#        first_name LAST_NAME gender  Age Hair_COLOR eye_Color  CUSTOMER_ID  \
# PRICE
# 199.99    Michael     Smith      M   58      brown     brown            9
#
#        FIRST_NAME GENDER  AGE        DATE    SKU     ITEM_DESCRIPTION
# PRICE
# 199.99    Michael      M   58  02/14/2015  38349  bottle of champagne

# %%
detailed_sales.to_csv('df_out.csv') #Dosya kaydetme
detailed_sales.to_csv('df_out.p')
